# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Mask_detection'
# Out:
# /content/drive/MyDrive/Mask_detection

# %%
# %cd '/content/drive/MyDrive/Mask_detection'
# !yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=10 imgsz=600 plots=true
# Out:
# /content/drive/MyDrive/Mask_detection
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model= /content/drive/MyDrive/Mask_detection/runs/detect/train/weights/best.pt conf= 0.25 source = /content/drive/MyDrive/Mask_detection/dataset/test/images
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
#
# image 1/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/102.jpg: 608x608 1 without_mask, 85.2ms
# image 2/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/104.jpg: 608x608 1 with_mask, 1 without_mask, 81.1ms
# image 3/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/109.jpg: 608x608 1 without_mask, 80.3ms
# image 4/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/110.jpg: 608x608 1 without_mask, 92.7ms
# image 5/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/112.jpg: 608x608 1 without_mask, 92.6ms
# image 6/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/12.jpg: 608x608 1 without_mask, 51.6ms
# image 7/160 /content/drive/MyDrive/Mask_detection/dataset/test/images/125.jpg: 608x608 1 without_mask, 51.0ms
# ...

# %%
# !yolo task=detect mode=predict model= /content/drive/MyDrive/Mask_detection/runs/detect/train/weights/best.pt conf= 0.25 source = /content/drive/MyDrive/Mask_detection/mask_detection.mp4
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (1/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 60.7ms
# video 1/1 (2/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 50.9ms
# video 1/1 (3/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 42.9ms
# video 1/1 (4/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 42.9ms
# video 1/1 (5/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 39.2ms
# video 1/1 (6/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 33.7ms
# video 1/1 (7/561) /content/drive/MyDrive/Mask_detection/mask_detection.mp4: 608x352 1 with_mask, 33.2ms
# ...
